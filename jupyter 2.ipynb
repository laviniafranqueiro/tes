# %%
import math
import re
import pandas as pd
import requests
from bs4 import BeautifulSoup
import csv
import re

# %%
url = 'https://www.kabum.com.br/computadores/notebooks'

headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
    (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"}

site = requests.get(url, headers=headers)
soup = BeautifulSoup(site.content, 'html.parser')
qtd_itens = soup.find('div', id="listingCount").get_text().strip()

index = qtd_itens.find(' ')
qtd = qtd_itens[:index]

# %%
dic_produtos = {'marca': [], 'preço': [], 'link': []}

for i in range(1,  150):
    url_pag = f'https://www.kabum.com.br/computadores/notebooks?page_number={i}&page_size=20&facet_filters=&sort=most_searched'
    site = requests.get(url_pag, headers=headers)
    soup = BeautifulSoup(site.content, 'lxml')
    produtos = soup.find_all('div', class_=re.compile('productCard'))

    for produto in produtos:
        marca = produto.find('span', class_=re.compile('nameCard')).get_text().strip()
        preço = produto.find('span', class_=re.compile('priceCard')).get_text().strip()
        link = produto.find('a', attrs={'href': re.compile('^')}).get('href')

        #print(marca, preço)

        assert isinstance(marca, object)
        dic_produtos['marca'].append(marca)
        dic_produtos['preço'].append(preço)
        dic_produtos['link'].append('https://www.kabum.com.br/' + link)

    #print(url_pag)
    
#data = pd.read_csv("preço_notebooks.csv")
# nome_arquivo_excel = 'preço_notebooks_excel.xlsx'
# data.to_excel(nome_arquivo_excel, index=False)
# df.to_csv("preço_notebooks.csv", index=False)

df = pd.DataFrame(dic_produtos)
df.head()
# Out:
#                                                marca        preço  \
# 0  Notebook Gamer Lenovo Gaming 3i Intel Core i5-...  R$ 4.199,99
# 1  Notebook Asus AMD Ryzen 5-3500U, 8GB RAM, SSD ...  R$ 3.099,99
# 2  Notebook Acer Aspire 5 Ryzen 7-5700U, 8GB RAM,...  R$ 3.599,99
# 3  Notebook Gamer Acer Nitro 5 Intel Core i7-1180...  R$ 5.199,99
# 4  Notebook Asus Intel Core i3 1005G1, 4GB RAM, 2...  R$ 1.949,99
#
#                                                 link
# 0  https://www.kabum.com.br//produto/373931/noteb...
# 1  https://www.kabum.com.br//produto/334039/noteb...
# 2  https://www.kabum.com.br//produto/308368/noteb...
# 3  https://www.kabum.com.br//produto/382898/noteb...
# 4  https://www.kabum.com.br//produto/369923/noteb...

# %%
df.tail(5)
# Out:
#                                                   marca        preço  \
# 2975  Fonte Carregador Acer Aspire 5000 Series 19v 3...     R$ 78,99
# 2976  Fonte Carregador Para Hp Chromebook 14 14-q029...    R$ 102,00
# 2977  Pasta De Couro Legítimo Nordweg - Italiano Caf...  R$ 1.640,49
# 2978  Fonte Carregador Para Hp 240 G4 Tpn-q129 19.5v...    R$ 102,00
# 2979  Fonte Carregador Para Hp Hp 246 G6 19,5v 3,33a...    R$ 102,00
#
#                                                    link
# 2975  https://www.kabum.com.br//produto/271413/fonte...
# 2976  https://www.kabum.com.br//produto/295302/fonte...
# 2977  https://www.kabum.com.br//produto/264863/pasta...
# 2978  https://www.kabum.com.br//produto/295653/fonte...
# 2979  https://www.kabum.com.br//produto/295807/fonte...

# %%
df.to_csv("jupyter2.csv")

# %%
df['marca'] = df['marca'].str.upper()

produto = input('Qual produto você deseja? ')
produto = produto.upper()

resultado = df[df['marca'].str.contains(fr'{produto}')]
resultado
# Out:
# Qual produto você deseja? notebook asus
#                                                   marca        preço  \
# 1     NOTEBOOK ASUS AMD RYZEN 5-3500U, 8GB RAM, SSD ...  R$ 3.099,99
# 4     NOTEBOOK ASUS INTEL CORE I3 1005G1, 4GB RAM, 2...  R$ 1.949,99
# 11    NOTEBOOK ASUS VIVOBOOK 15 INTEL CORE I5-1135G7...  R$ 3.699,99
# 15    NOTEBOOK ASUS AMD RYZEN 5-3500U, 8GB RAM, SSD ...  R$ 2.999,99
# 19    NOTEBOOK ASUS INTEL CORE I5-1035G1, 8GB, SSD 2...  R$ 3.369,99
# ...                                                 ...          ...
# 2907  TECLADO P/  NOTEBOOK ASUS ROG STRIX GL553 - US...    R$ 496,00
# 2937  FONTE P/ NOTEBOOK ASUS X44C K43E K43U A43E X54...     R$ 76,77
# 2938  FONTE CARREGADOR PARA NOTEBOOK ASUS X54 X53 19...     R$ 76,77
# 2940  FONTE CARREGADOR PARA NOTEBOOK ASUS K43E SERIE...     R$ 76,77
# 2957  NOTEBOOK ASUS X543UA, INTEL I, 16GB RAM, SSD 2...  R$ 4.122,49
#
#                                                    link
# 1     https://www.kabum.com.br//produto/334039/noteb...
# 4     https://www.kabum.com.br//produto/369923/noteb...
# 11    https://www.kabum.com.br//produto/430132/noteb...
# 15    https://www.kabum.com.br//produto/334040/noteb...
# 19    https://www.kabum.com.br//produto/268409/noteb...
# ...                                                 ...
# 2907  https://www.kabum.com.br//produto/285465/tecla...
# 2937  https://www.kabum.com.br//produto/296215/fonte...
# 2938  https://www.kabum.com.br//produto/296289/fonte...
# 2940  https://www.kabum.com.br//produto/296314/fonte...
# 2957  https://www.kabum.com.br//produto/266063/noteb...
#
# [113 rows x 3 columns]

# %%
df['marca'] = df['marca'].str.upper()

produto = input('Qual produto você deseja? ')
produto = produto.upper()

# função para criar os links clicáveis
def criar_link(link):
    return f'<a href="{link}" target="_blank">{link}</a>'

df['Links Clicáveis'] = df['link'].apply(criar_link)
df.drop(['link'], axis=1, inplace=True)

resultado = df[df['marca'].str.contains(fr'{produto}')]

display(HTML(resultado.to_html(escape=False)))
# Out:
# Qual produto você deseja? macbook
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>marca</th>
#       <th>preço</th>
#       <th>Links Clicáveis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>49</th>
#       <td>MACBOOK AIR M1, 8GB, 256GB SSD, TELA 13.3 POLEGADAS, SPACE GRAY - MGN63LL/A</td>
#       <td>R$ 6.599,00</td>
#       <td><a href="https://www.kabum.com.br//produto/160497/macbook-air-m1-8gb-256gb-ssd-tela-13-3-polegadas-space-gray-mgn63ll-a" target="_blank">https://www.kabum.com.br//produto/160497/macbook-air-m1-8gb-256gb-ssd-tela-13-3-polegadas-space-gray-mgn63ll-a</a></td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>MACBOOK AIR M1 8GB, 256GB SSD, TELA 13.3", GOLD, 2020 - MGND3LL/A</td>
#       <td>R$ 6.697,49</td>
#       <td><a href="https://www.kabum.com.br//produto/164867/macbook-air-m1-8gb-256gb-ssd-tela-13-3-gold-2020-mgnd3ll-a" target="_blank">https://www.kabum.com.br//produto/164867/macbook-air-m1-8gb-256gb-ssd-tela-13-3-gold-2020-mgnd3ll-a</a></td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>MACBOOK AIR M1 8GB, 256GB SSD, TELA 13.3", SPACE GRAY, 2020 - MGN63LL/A</td>
#       <td>R$ 6.697,49</td>
#       <td><a href="https://www.kabum.com.br//produto/164868/macbook-air-m1-8gb-256gb-ssd-tela-13-3-space-gray-2020-mgn63ll-a" target="_blank">https://www.kabum.com.br//produto/164868/macbook-air-m1-8gb-256gb-ssd-tela-13-3-space-gray-2020-mgn63ll-a</a></td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>MACBOOK APPLE AIR, M1, 8GB RAM, SSD 256GB, 13 POLEGADAS, PRATA</td>
#       <td>R$ 6.279,00</td>
#       <td><a href="https://www.kabum.com.br//produto/348125/macbook-apple-air-m1-8gb-ram-ssd-256gb-13-polegadas-prata" target="_blank">https://www.kabum.com.br//produto/348125/macbook-apple-air-m1-8gb-ram-ssd-256gb-13-polegadas-prata</a></td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>APPLE MACBOOK PRO, 14 POLEGADAS, CHIP M2 PRO, 2022 10C, CPU/16C GPU/16GB/512GB, CINZA ESPACIAL</td>
#       <td>R$ 14.724,99</td>
#       <td><a href="https://www.kabum.com.br//produto/462256/apple-macbook-pro-14-polegadas-chip-m2-pro-2022-10c-cpu-16c-gpu-16gb-512gb-cinza-espacial" target="_blank">https://www.kabum.com.br//produto/462256/apple-macbook-pro-14-polegadas-chip-m2-pro-2022-10c-cpu-16c-gpu-16gb-512gb-cinza-espacial</a></td>
#     </tr>
#     <tr>
#       <th>105</th>
#       <td>APPLE MACBOOK AIR 2022 CHIP M2 8C, CPU 8C, GPU 8GB, SSD 256GB - MEIA-NOITE</td>
#       <td>R$ 8.597,49</td>
#       <td><a href="https://www.kabum.com.br//produto/422436/apple-macbook-air-2022-chip-m2-8c-cpu-8c-gpu-8gb-ssd-256gb-meia-noite" target="_blank">https://www.kabum.com.br//produto/422436/apple-macbook-air-2022-chip-m2-8c-cpu-8c-gpu-8gb-ssd-256gb-meia-noite</a></td>
#     </tr>
#     <tr>
#       <th>127</th>
#       <td>MACBOOK APPLE AIR, PROCESSADOR M1, 8GB, SSD 256GB, TELA 13.3 POLEGADAS, RETINA IPS, MACOS, CINZA-ESPACIAL - MGN63BZ/A</td>
#       <td>R$ 6.999,00</td>
#       <td><a href="https://www.kabum.com.br//produto/357442/macbook-apple-air-processador-m1-8gb-ssd-256gb-tela-13-3-polegadas-retina-ips-macos-cinza-espacial-mgn63bz-a" target="_blank">https://www.kabum.com.br//produto/357442/macbook-apple-air-processador-m1-8gb-ssd-256gb-tela-13-3-polegadas-retina-ips-macos-cinza-espacial-mgn63bz-a</a></td>
#     </tr>
#     <tr>
#       <th>150</th>
#       <td>MACBOOK AIR 2022 M2 8GB RAM 256GB SSD APPLE M2 10-CORE GPU CINZA ESPACIAL</td>
#       <td>R$ 8.644,99</td>
#       <td><a href="https://www.kabum.com.br//produto/422435/macbook-air-2022-m2-8gb-ram-256gb-ssd-apple-m2-10-core-gpu-cinza-espacial" target="_blank">https://www.kabum.com.br//produto/422435/macbook-air-2022-m2-8gb-ram-256gb-ssd-apple-m2-10-core-gpu-cinza-espacial</a></td>
#     </tr>
#     <tr>
#       <th>157</th>
#       <td>APPLE MACBOOK PRO 13" (M2 DA APPLE, COM 8 CPU, 10 GPU, 8GB RAM, 256GB SSD) - CINZA-ESPACIAL</td>
#       <td>R$ 9.499,99</td>
#       <td><a href="https://www.kabum.com.br//produto/367363/apple-macbook-pro-13-m2-da-apple-com-8-cpu-10-gpu-8gb-ram-256gb-ssd-cinza-espacial" target="_blank">https://www.kabum.com.br//produto/367363/apple-macbook-pro-13-m2-da-apple-com-8-cpu-10-gpu-8gb-ram-256gb-ssd-cinza-espacial</a></td>
#     </tr>
#     <tr>
#       <th>186</th>
#       <td>MACBOOK PRO APPLE M2,  MNEH3LL 2022 DE 13.3 M2, 8GB, SSD 256GB - SPACE GRAY</td>
#       <td>R$ 10.799,10</td>
#       <td><a href="https://www.kabum.com.br//produto/397259/macbook-pro-apple-m2-mneh3ll-2022-de-13-3-m2-8gb-ssd-256gb-space-gray" target="_blank">https://www.kabum.com.br//produto/397259/macbook-pro-apple-m2-mneh3ll-2022-de-13-3-m2-8gb-ssd-256gb-space-gray</a></td>
#     </tr>
#     <tr>
#       <th>191</th>
#       <td>MACBOOK APPLE AIR 2022 M2 MLY13LL/A, 8GB, 256GB, M2 10-CORE, GPU ESTELAR</td>
#       <td>R$ 8.499,00</td>
#       <td><a href="https://www.kabum.com.br//produto/447972/macbook-apple-air-2022-m2-mly13ll-a-8gb-256gb-m2-10-core-gpu-estelar" target="_blank">https://www.kabum.com.br//produto/447972/macbook-apple-air-2022-m2-mly13ll-a-8gb-256gb-m2-10-core-gpu-estelar</a></td>
#     </tr>
#     <tr>
#       <th>325</th>
#       <td>APPLE MACBOOK PRO, M2 PRO 2022 12C CPU, 19C GPU, 16GB, 1TB, TELA 16 POLEGADAS, CINZA ESPACIAL</td>
#       <td>R$ 18.999,99</td>
#       <td><a href="https://www.kabum.com.br//produto/453970/apple-macbook-pro-m2-pro-2022-12c-cpu-19c-gpu-16gb-1tb-tela-16-polegadas-cinza-espacial" target="_blank">https://www.kabum.com.br//produto/453970/apple-macbook-pro-m2-pro-2022-12c-cpu-19c-gpu-16gb-1tb-tela-16-polegadas-cinza-espacial</a></td>
#     </tr>
#     <tr>
#       <th>334</th>
#       <td>APPLE MACBOOK PRO 13" (M2 DA APPLE, COM 8 CPU, 10 GPU, 8GB RAM, 512GB SSD) - CINZA-ESPACIAL</td>
#       <td>R$ 10.829,99</td>
#       <td><a href="https://www.kabum.com.br//produto/367360/apple-macbook-pro-13-m2-da-apple-com-8-cpu-10-gpu-8gb-ram-512gb-ssd-cinza-espacial" target="_blank">https://www.kabum.com.br//produto/367360/apple-macbook-pro-13-m2-da-apple-com-8-cpu-10-gpu-8gb-ram-512gb-ssd-cinza-espacial</a></td>
#     </tr>
#     <tr>
#       <th>356</th>
#       <td>MACBOOK PRO I7, 16GB RAM, 512GB SSD, TELA 16" SPACE GRAY - MVVJ2LL/A</td>
#       <td>R$ 33.209,10</td>
#       <td><a href="https://www.kabum.com.br//produto/244544/macbook-pro-i7-16gb-ram-512gb-ssd-tela-16-space-gray-mvvj2ll-a" target="_blank">https://www.kabum.com.br//produto/244544/macbook-pro-i7-16gb-ram-512gb-ssd-tela-16-space-gray-mvvj2ll-a</a></td>
#     </tr>
#     <tr>
#       <th>364</th>
#       <td>APPLE MACBOOK PRO 2022, 16GB, 256GB, CHIP M2 8C CPU 10C GPU, TELA 13 POLEGADAS - CINZA ESPACIAL</td>
#       <td>R$ 12.824,99</td>
#       <td><a href="https://www.kabum.com.br//produto/456305/apple-macbook-pro-2022-16gb-256gb-chip-m2-8c-cpu-10c-gpu-tela-13-polegadas-cinza-espacial" target="_blank">https://www.kabum.com.br//produto/456305/apple-macbook-pro-2022-16gb-256gb-chip-m2-8c-cpu-10c-gpu-tela-13-polegadas-cinza-espacial</a></td>
#     </tr>
#     <tr>
#       <th>429</th>
#       <td>FONTE CARREGADOR PARA NOTEBOOK APPLE MACBOOK PRO A1278 16.5V 3.65A 60W PINO MAGSAFE L</td>
#       <td>R$ 169,99</td>
#       <td><a href="https://www.kabum.com.br//produto/237437/fonte-carregador-para-notebook-apple-macbook-pro-a1278-16-5v-3-65a-60w-pino-magsafe-l" target="_blank">https://www.kabum.com.br//produto/237437/fonte-carregador-para-notebook-apple-macbook-pro-a1278-16-5v-3-65a-60w-pino-magsafe-l</a></td>
#     </tr>
#     <tr>
#       <th>460</th>
#       <td>CARREGADOR BESTBATTERY PARA MACBOOK 14,85V, 45W, 3,05A MAGN</td>
#       <td>R$ 128,67</td>
#       <td><a href="https://www.kabum.com.br//produto/429035/carregador-bestbattery-para-macbook-14-85v-45w-3-05a-magn" target="_blank">https://www.kabum.com.br//produto/429035/carregador-bestbattery-para-macbook-14-85v-45w-3-05a-magn</a></td>
#     </tr>
#     <tr>
#       <th>463</th>
#       <td>APPLE MACBOOK AIR 13,6” M2 8GB RAM</td>
#       <td>R$ 9.719,10</td>
#       <td><a href="https://www.kabum.com.br//produto/402663/apple-macbook-air-13-6-m2-8gb-ram" target="_blank">https://www.kabum.com.br//produto/402663/apple-macbook-air-13-6-m2-8gb-ram</a></td>
#     </tr>
#     <tr>
#       <th>505</
